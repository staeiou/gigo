# %%
import pandas as pd
import numpy as np
import seaborn as sns
import glob
import os
import datetime
import lxml.etree as ET
from xml.dom import minidom
# %matplotlib inline

# %% [markdown]
# ## Import processed data

# %%
df_all = pd.read_hdf("processed_data/arxiv-oai-af.h5", key='df')
df_ml = pd.read_hdf("processed_data/arxiv-oai-af-anyml.h5", key='df')

# %%
df_all[0:2].transpose()
# Out:
#                                                                 0  \
# abstract          We consider the two-nucleon weak interaction...
# anymlcat                                                        0
# arxiv_id                                                0907.3995
# author_text                       J. W. Shin, S. Ando, C. H. Hyun
# categories                             [nucl-th, hep-ph, nucl-ex]
# created                                                2009-07-23
# cs.AI                                                           0
# cs.CL                                                           0
# cs.LG                                                           0
# cs.SI                                                           0
# doi                                    10.1103/PhysRevC.81.055501
# num_authors                                                     3
# num_categories                                                  3
# stat.ML                                                         0
# title           Parity-violating polarization in $np \to d\gam...
# updated                                                       NaN
#
#                                                                 1
# abstract          A brief introduction is given in the generic...
# anymlcat                                                        0
# arxiv_id                                         cond-mat/0302169
# author_text     D. van der Marel, H. J. A. Molegraaf, C. Presu...
# categories                   [cond-mat.supr-con, cond-mat.str-el]
# created                                                2003-02-10
# cs.AI                                                           0
# cs.CL                                                           0
# cs.LG                                                           0
# cs.SI                                                           0
# doi                                                           NaN
# num_authors                                                     4
# num_categories                                                  2
# stat.ML                                                         0
# title                 Superconductivity by Kinetic Energy Saving?
# updated                                                       NaN

# %% [markdown]
# ## Processing

# %%
def list_to_string(l):
    return ', '.join(l)

# %%
def remove_initial_space(s):
    if s[0] == ' ':
        return s[1:]
    else:
        return s

# %%
df_all.abstract = df_all.abstract.apply(remove_initial_space)
df_all.abstract = df_all.abstract.apply(str.replace,args=("\n"," "))
df_all.abstract = df_all.abstract.apply(str.replace,args=("  "," "))
df_all.abstract = df_all.abstract.apply(str.replace,args=("  "," "))
df_all.title = df_all.title.apply(str.replace,args=("\n"," "))
df_all.title = df_all.title.apply(str.replace,args=("  "," "))
df_all.title = df_all.title.apply(str.replace,args=("  "," "))

# %% [markdown]
# ### Get to one dataframe for each category

# %%
df_all['categories_str'] = df_all.categories.apply(list_to_string)

# %%
categories = []

for row in df_all.iterrows():
    for cat in row[1].categories:
        #print(cat)
        if cat not in categories:
            categories.append(cat)

# %%
categories.sort()
len(categories)
# Out:
# 175

# %%
df_dict = {}

for cat in categories:
    print(cat)
    df_dict[cat] = df_all[df_all['categories_str'].str.contains(cat)]
    print(len(df_dict[cat]))
# Out:
# acc-phys
# 49
# adap-org
# 584
# alg-geom
# 1423
# ao-sci
# 17
# astro-ph
# 244091
# astro-ph.CO
# 45076
# astro-ph.EP
# 14423
# astro-ph.GA
# 32627
# astro-ph.HE
# 30821
# astro-ph.IM
# 14138
# astro-ph.SR
# 35957
# atom-ph
# 13857
# bayes-an
# 16
# chao-dyn
# 2398
# chem-ph
# 11380
# cmp-lg
# 894
# comp-gas
# 221
# cond-mat
# 256186
# cond-mat.dis-nn
# 16710
# cond-mat.mes-hall
# 58630
# cond-mat.mtrl-sci
# 54620
# cond-mat.other
# 12519
# cond-mat.quant-gas
# 12862
# cond-mat.soft
# 26221
# cond-mat.stat-mech
# 52945
# cond-mat.str-el
# 50009
# cond-mat.supr-con
# 32427
# cs.AI
# 15873
# cs.AR
# 1160
# cs.CC
# 6218
# cs.CE
# 2813
# cs.CG
# 3530
# cs.CL
# 10610
# cs.CR
# 9142
# cs.CV
# 21472
# cs.CY
# 5234
# cs.DB
# 3868
# cs.DC
# 8177
# cs.DL
# 2498
# cs.DM
# 7408
# cs.DS
# 11975
# cs.ET
# 1292
# cs.FL
# 2444
# cs.GL
# 147
# cs.GR
# 1252
# cs.GT
# 4988
# cs.HC
# 3352
# cs.IR
# 4814
# cs.IT
# 26451
# cs.LG
# 23912
# cs.LO
# 8598
# cs.MA
# 2061
# cs.MM
# 1822
# cs.MS
# 1175
# cs.NA
# 2414
# cs.NE
# 5416
# cs.NI
# 10745
# cs.OH
# 1734
# cs.OS
# 403
# cs.PF
# 1602
# cs.PL
# 3631
# cs.RO
# 4845
# cs.SC
# 1370
# cs.SD
# 1668
# cs.SE
# 5216
# cs.SI
# 8920
# cs.SY
# 7178
# dg-ga
# 732
# econ.EM
# 473
# econ.GN
# 68
# econ.TH
# 58
# eess.AS
# 723
# eess.IV
# 478
# eess.SP
# 1972
# funct-an
# 427
# gr-qc
# 73107
# hep-ex
# 37063
# hep-lat
# 21717
# hep-ph
# 138408
# hep-th
# 125444
# math-ph
# 54555
# math.AC
# 8387
# math.AG
# 35109
# math.AP
# 33114
# math.AT
# 9571
# math.CA
# 14329
# math.CO
# 37395
# math.CT
# 4715
# math.CV
# 10774
# math.DG
# 28038
# math.DS
# 20758
# math.FA
# 18407
# math.GM
# 2369
# math.GN
# 3110
# math.GR
# 13911
# math.GT
# 15244
# math.HO
# 2112
# math.IT
# 26451
# math.KT
# 4040
# math.LO
# 7756
# math.MG
# 6629
# math.MP
# 54555
# math.NA
# 15742
# math.NT
# 24667
# math.OA
# 8798
# math.OC
# 18521
# math.PR
# 33547
# math.QA
# 14501
# math.RA
# 10933
# math.RT
# 16667
# math.SG
# 6266
# math.SP
# 6178
# math.ST
# 12106
# mtrl-th
# 262
# nlin.AO
# 4593
# nlin.CD
# 12110
# nlin.CG
# 1132
# nlin.PS
# 6571
# nlin.SI
# 9047
# nucl-ex
# 18070
# nucl-th
# 42963
# patt-sol
# 650
# physics.acc-ph
# 5054
# physics.ao-ph
# 3113
# physics.app-ph
# 2419
# physics.atm-clus
# 1916
# physics.atom-ph
# 13802
# physics.bio-ph
# 9190
# physics.chem-ph
# 11259
# physics.class-ph
# 5674
# physics.comp-ph
# 10319
# physics.data-an
# 6472
# physics.ed-ph
# 2284
# physics.flu-dyn
# 13318
# physics.gen-ph
# 8581
# physics.geo-ph
# 3539
# physics.hist-ph
# 3004
# physics.ins-det
# 11675
# physics.med-ph
# 2598
# physics.optics
# 23793
# physics.plasm-ph
# 9242
# physics.pop-ph
# 1592
# physics.soc-ph
# 13220
# physics.space-ph
# 3195
# plasm-ph
# 9252
# q-alg
# 1578
# q-bio
# 25529
# q-bio.BM
# 3414
# q-bio.CB
# 1430
# q-bio.GN
# 1961
# q-bio.MN
# 2590
# q-bio.NC
# 4623
# q-bio.OT
# 793
# q-bio.PE
# 6451
# q-bio.QM
# 4908
# q-bio.SC
# 1264
# q-bio.TO
# 1188
# q-fin.CP
# 1110
# q-fin.EC
# 648
# q-fin.GN
# 1749
# q-fin.MF
# 928
# q-fin.PM
# 936
# q-fin.PR
# 1366
# q-fin.RM
# 1139
# q-fin.ST
# 2077
# q-fin.TR
# 916
# quant-ph
# 89799
# solv-int
# 1413
# stat.AP
# 7211
# stat.CO
# 3602
# stat.ME
# 9925
# stat.ML
# 18673
# stat.OT
# 534
# stat.TH
# 12106
# supr-con
# 32530

# %%
df_dict_generic = df_dict.copy()

# %%
for cat in categories:
    df_dict_generic[cat].drop(labels=['anymlcat', 'cs.AI', 'cs.CL', 'cs.LG', 'cs.SI', 'stat.ML', 'categories'],
                              axis=1, inplace=True)
# Out:
# /home/staeiou/conda/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # File output

# %%
os.system("rm processed_data/arxiv_oaiaf_catkey.h5")
# Out:
# 256

# %%
os.system("rm processed_data/per_category/*")
# Out:
# 0

# %%
for cat in categories:
    fn = "processed_data/per_category/" + cat
    df_dict_generic[cat].to_csv(fn+".tsv", sep="\t", mode="w")
    df_dict_generic[cat].to_hdf(fn+".h5", key="df", mode="w")
    
    zip_str = "zip -9 " + fn+".tsv.zip " + fn + ".tsv"
    bzip2_str = "bzip2 -kz9 " + fn + ".tsv"
    xz_str = "xz -kz9 " + fn + ".tsv"

        
    #os.system(zip_str)
    #os.system(bzip2_str)
    os.system(xz_str)
    
    xz_size = round(os.path.getsize(fn+".tsv.xz")/1024/1024,2)
    
    print(fn, xz_size, "M")
    
    cat_key = cat.replace(".","_")
    cat_key = cat_key.replace("-","_")
    df_dict_generic[cat].to_hdf("processed_data/arxiv_oaiaf_catkey.h5",
                                key=cat_key, mode="a")
# Out:
# /home/staeiou/conda/lib/python3.5/site-packages/pandas/core/generic.py:1282: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['abstract', 'arxiv_id', 'author_text', 'created', 'doi', 'title', 'updated', 'categories_str']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# processed_data/per_category/acc-phys 0.01 M
# processed_data/per_category/adap-org 0.14 M
# processed_data/per_category/alg-geom 0.25 M
# processed_data/per_category/ao-sci 0.01 M
# processed_data/per_category/astro-ph 70.97 M
# processed_data/per_category/astro-ph.CO 13.57 M
# processed_data/per_category/astro-ph.EP 5.07 M
# processed_data/per_category/astro-ph.GA 11.32 M
# processed_data/per_category/astro-ph.HE 9.32 M
# processed_data/per_category/astro-ph.IM 4.71 M
# processed_data/per_category/astro-ph.SR 11.65 M
# processed_data/per_category/atom-ph 3.16 M
# processed_data/per_category/bayes-an 0.01 M
# processed_data/per_category/chao-dyn 0.5 M
# processed_data/per_category/chem-ph 3.09 M
# processed_data/per_category/cmp-lg 0.2 M
# processed_data/per_category/comp-gas 0.06 M
# processed_data/per_category/cond-mat 56.28 M
# processed_data/per_category/cond-mat.dis-nn 3.74 M
# processed_data/per_category/cond-mat.mes-hall 12.76 M
# processed_data/per_category/cond-mat.mtrl-sci 13.28 M
# processed_data/per_category/cond-mat.other 2.87 M
# processed_data/per_category/cond-mat.quant-gas 2.86 M
# processed_data/per_category/cond-mat.soft 6.32 M
# processed_data/per_category/cond-mat.stat-mech 11.23 M
# processed_data/per_category/cond-mat.str-el 10.9 M
# processed_data/per_category/cond-mat.supr-con 7.09 M
# processed_data/per_category/cs.AI 4.17 M
# processed_data/per_category/cs.AR 0.36 M
# processed_data/per_category/cs.CC 1.59 M
# processed_data/per_category/cs.CE 0.88 M
# processed_data/per_category/cs.CG 0.9 M
# processed_data/per_category/cs.CL 2.6 M
# processed_data/per_category/cs.CR 2.54 M
# processed_data/per_category/cs.CV 5.86 M
# processed_data/per_category/cs.CY 1.6 M
# processed_data/per_category/cs.DB 1.16 M
# processed_data/per_category/cs.DC 2.42 M
# processed_data/per_category/cs.DL 0.74 M
# processed_data/per_category/cs.DM 1.73 M
# processed_data/per_category/cs.DS 3.24 M
# processed_data/per_category/cs.ET 0.4 M
# processed_data/per_category/cs.FL 0.54 M
# processed_data/per_category/cs.GL 0.04 M
# processed_data/per_category/cs.GR 0.39 M
# processed_data/per_category/cs.GT 1.41 M
# processed_data/per_category/cs.HC 1.02 M
# processed_data/per_category/cs.IR 1.39 M
# processed_data/per_category/cs.IT 6.37 M
# processed_data/per_category/cs.LG 6.31 M
# processed_data/per_category/cs.LO 1.95 M
# processed_data/per_category/cs.MA 0.62 M
# processed_data/per_category/cs.MM 0.56 M
# processed_data/per_category/cs.MS 0.33 M
# processed_data/per_category/cs.NA 0.66 M
# processed_data/per_category/cs.NE 1.51 M
# processed_data/per_category/cs.NI 3.01 M
# processed_data/per_category/cs.OH 0.5 M
# processed_data/per_category/cs.OS 0.13 M
# processed_data/per_category/cs.PF 0.5 M
# processed_data/per_category/cs.PL 0.95 M
# processed_data/per_category/cs.RO 1.41 M
# processed_data/per_category/cs.SC 0.32 M
# processed_data/per_category/cs.SD 0.48 M
# processed_data/per_category/cs.SE 1.43 M
# processed_data/per_category/cs.SI 2.65 M
# processed_data/per_category/cs.SY 1.86 M
# processed_data/per_category/dg-ga 0.13 M
# processed_data/per_category/econ.EM 0.15 M
# processed_data/per_category/econ.GN 0.03 M
# processed_data/per_category/econ.TH 0.02 M
# processed_data/per_category/eess.AS 0.22 M
# processed_data/per_category/eess.IV 0.17 M
# processed_data/per_category/eess.SP 0.61 M
# processed_data/per_category/funct-an 0.08 M
# processed_data/per_category/gr-qc 14.53 M
# processed_data/per_category/hep-ex 7.71 M
# processed_data/per_category/hep-lat 3.78 M
# processed_data/per_category/hep-ph 25.34 M
# processed_data/per_category/hep-th 22.55 M
# processed_data/per_category/math-ph 10.08 M
# processed_data/per_category/math.AC 1.33 M
# processed_data/per_category/math.AG 5.15 M
# processed_data/per_category/math.AP 5.43 M
# processed_data/per_category/math.AT 1.59 M
# processed_data/per_category/math.CA 2.32 M
# processed_data/per_category/math.CO 6.6 M
# processed_data/per_category/math.CT 0.84 M
# processed_data/per_category/math.CV 1.65 M
# processed_data/per_category/math.DG 4.21 M
# processed_data/per_category/math.DS 3.79 M
# processed_data/per_category/math.FA 3.0 M
# processed_data/per_category/math.GM 0.41 M
# processed_data/per_category/math.GN 0.53 M
# processed_data/per_category/math.GR 2.16 M
# processed_data/per_category/math.GT 2.34 M
# processed_data/per_category/math.HO 0.41 M
# processed_data/per_category/math.IT 6.37 M
# processed_data/per_category/math.KT 0.66 M
# processed_data/per_category/math.LO 1.34 M
# processed_data/per_category/math.MG 1.17 M
# processed_data/per_category/math.MP 10.08 M
# processed_data/per_category/math.NA 3.45 M
# processed_data/per_category/math.NT 3.73 M
# processed_data/per_category/math.OA 1.46 M
# processed_data/per_category/math.OC 4.13 M
# processed_data/per_category/math.PR 6.26 M
# processed_data/per_category/math.QA 2.3 M
# processed_data/per_category/math.RA 1.74 M
# processed_data/per_category/math.RT 2.61 M
# processed_data/per_category/math.SG 1.02 M
# processed_data/per_category/math.SP 1.08 M
# processed_data/per_category/math.ST 2.69 M
# processed_data/per_category/mtrl-th 0.07 M
# processed_data/per_category/nlin.AO 1.21 M
# processed_data/per_category/nlin.CD 2.62 M
# processed_data/per_category/nlin.CG 0.29 M
# processed_data/per_category/nlin.PS 1.48 M
# processed_data/per_category/nlin.SI 1.55 M
# processed_data/per_category/nucl-ex 4.11 M
# processed_data/per_category/nucl-th 8.18 M
# processed_data/per_category/patt-sol 0.15 M
# processed_data/per_category/physics.acc-ph 1.2 M
# processed_data/per_category/physics.ao-ph 0.98 M
# processed_data/per_category/physics.app-ph 0.8 M
# processed_data/per_category/physics.atm-clus 0.52 M
# processed_data/per_category/physics.atom-ph 3.15 M
# processed_data/per_category/physics.bio-ph 2.66 M
# processed_data/per_category/physics.chem-ph 3.07 M
# processed_data/per_category/physics.class-ph 1.34 M
# processed_data/per_category/physics.comp-ph 2.81 M
# processed_data/per_category/physics.data-an 1.79 M
# processed_data/per_category/physics.ed-ph 0.58 M
# processed_data/per_category/physics.flu-dyn 3.54 M
# processed_data/per_category/physics.gen-ph 1.87 M
# processed_data/per_category/physics.geo-ph 1.14 M
# processed_data/per_category/physics.hist-ph 0.74 M
# processed_data/per_category/physics.ins-det 3.27 M
# processed_data/per_category/physics.med-ph 0.88 M
# processed_data/per_category/physics.optics 5.45 M
# processed_data/per_category/physics.plasm-ph 2.37 M
# processed_data/per_category/physics.pop-ph 0.42 M
# processed_data/per_category/physics.soc-ph 3.64 M
# processed_data/per_category/physics.space-ph 1.03 M
# processed_data/per_category/plasm-ph 2.37 M
# processed_data/per_category/q-alg 0.26 M
# processed_data/per_category/q-bio 7.38 M
# processed_data/per_category/q-bio.BM 1.04 M
# processed_data/per_category/q-bio.CB 0.47 M
# processed_data/per_category/q-bio.GN 0.67 M
# processed_data/per_category/q-bio.MN 0.81 M
# processed_data/per_category/q-bio.NC 1.46 M
# processed_data/per_category/q-bio.OT 0.26 M
# processed_data/per_category/q-bio.PE 1.92 M
# processed_data/per_category/q-bio.QM 1.59 M
# processed_data/per_category/q-bio.SC 0.4 M
# processed_data/per_category/q-bio.TO 0.42 M
# processed_data/per_category/q-fin.CP 0.28 M
# processed_data/per_category/q-fin.EC 0.2 M
# processed_data/per_category/q-fin.GN 0.5 M
# processed_data/per_category/q-fin.MF 0.22 M
# processed_data/per_category/q-fin.PM 0.23 M
# processed_data/per_category/q-fin.PR 0.31 M
# processed_data/per_category/q-fin.RM 0.3 M
# processed_data/per_category/q-fin.ST 0.53 M
# processed_data/per_category/q-fin.TR 0.24 M
# processed_data/per_category/quant-ph 17.7 M
# processed_data/per_category/solv-int 0.24 M
# processed_data/per_category/stat.AP 2.17 M
# processed_data/per_category/stat.CO 0.97 M
# processed_data/per_category/stat.ME 2.56 M
# processed_data/per_category/stat.ML 4.93 M
# processed_data/per_category/stat.OT 0.17 M
# processed_data/per_category/stat.TH 2.69 M
# processed_data/per_category/supr-con 7.11 M

# %%
# !ls -lah "processed_data/per_category/*.xz"
# Out:
# ls: cannot access 'processed_data/per_category/*.xz': No such file or directory
