# %%
import pandas as pd

# %%
pd.read_json("h.json")
# Out:
#       group                      id  isPagenote  isReply  \
# 0  ErPXAXMd  VQWcwqprEeinZduyzebEYg       False    False
# 1  ErPXAXMd  YRusNqprEeiVOfPUMhc4jQ       False    False
# 2  ErPXAXMd  aguP5qprEeiR9VNxDca-Gg       False    False
# 3  ErPXAXMd  h_FGrqprEeiJwbfPaXeTkA       False    False
# 4  ErPXAXMd  RrQXzqpsEeiHlZsKsePG_g       False    False
# 5  ErPXAXMd  tPkRfKprEei5Kgsb8zsktw        True    False
# 6  ErPXAXMd  qnpeQKprEeiXi38vOKQjbA        True    False
# 7  ErPXAXMd  e_hGDqprEeiWOX97EDGUnA       False    False
#
#                                                quote refs        tags  \
# 0  Abstract—Although  shill  bidding  is  a  comm...   []  [abstract]
# 1        Clustering and Labelling Auction Fraud Data   []     [title]
# 2                 Ahmad Alzahrani and Samira Sadaoui   []   [authors]
# 3                                               2018   []      [year]
# 4  Since   SB   data   are   not   labeled,   dat...   []  [labeling]
# ...
